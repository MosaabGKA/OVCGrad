# %%
import pandas as pd

# %%
patients = pd.read_csv('ClinicalPreprocessing/ProcessedData/patients.csv')
patients.head()
# Out:
#                                 case_id  submitter_id  \
# 0  005a6517-2e5a-4ea3-ab36-531522723607  TCGA-61-1740
# 1  00630714-7ab3-44e1-afff-186300edae44  TCGA-13-0761
# 2  01abf2cf-541c-4610-8ce8-318016db6e59  TCGA-25-2390
# 3  01ea6354-137b-47f3-9021-a01a382b1147  TCGA-29-1766
# 4  02594e5e-8751-47c1-9245-90c66984b665  TCGA-09-2051
#
#                      primary_site                           disease_type  \
# 0                           Ovary  Cystic, Mucinous and Serous Neoplasms
# 1                           Ovary  Cystic, Mucinous and Serous Neoplasms
# 2                           Ovary  Cystic, Mucinous and Serous Neoplasms
# 3  Retroperitoneum and peritoneum  Cystic, Mucinous and Serous Neoplasms
# 4                           Ovary  Cystic, Mucinous and Serous Neoplasms
#
#        consent_type index_date     state                  updated_datetime  \
# 0  Consent by Death  Diagnosis  released  2025-01-06T21:35:19.822934-06:00
# ...

# %%
follow_ups = pd.read_csv('ClinicalPreprocessing/ProcessedData/follow_ups.csv')
follow_ups.head()
# Out:
#                            follow_up_id                               case_id  \
# 0  1d266ca2-f3e7-473d-93b0-2b8f2af773b8  005a6517-2e5a-4ea3-ab36-531522723607
# 1  781533f7-4c3d-423f-aa83-9718cd9a9f12  005a6517-2e5a-4ea3-ab36-531522723607
# 2  a9f13da7-d7da-4cd4-b3a0-658b70ba3404  005a6517-2e5a-4ea3-ab36-531522723607
# 3  11df2a10-76aa-4a25-9d85-88a32930b661  00630714-7ab3-44e1-afff-186300edae44
# 4  36407ad0-6db2-4a93-aa80-43fce25d9195  00630714-7ab3-44e1-afff-186300edae44
#
#               submitter_id         timepoint_category  days_to_follow_up  \
# 0   TCGA-61-1740_follow_up               Last Contact               74.0
# 1  TCGA-61-1740_follow_up3  Prior to Adjuvant Therapy                NaN
# 2  TCGA-61-1740_follow_up2                  Follow-up               74.0
# 3  TCGA-13-0761_follow_up5     Post Initial Treatment              424.0
# 4  TCGA-13-0761_follow_up4     Post Initial Treatment              424.0
#
# ...

# %%
diagnoses = pd.read_csv('ClinicalPreprocessing/ProcessedData/diagnoses.csv')
diagnoses.head()
# Out:
#                            diagnosis_id                               case_id  \
# 0  6bce9673-5223-59f5-b869-2366b5e46652  005a6517-2e5a-4ea3-ab36-531522723607
# 1  6e210a80-985b-457d-903f-65cdb7101cce  00630714-7ab3-44e1-afff-186300edae44
# 2  f12065b8-bf43-4d3d-a6b2-f3e42796d92f  00630714-7ab3-44e1-afff-186300edae44
# 3  fa91f476-c060-5d7c-8454-e8724950c497  00630714-7ab3-44e1-afff-186300edae44
# 4  dc0adbeb-b689-5242-9257-1d892eef26b1  01abf2cf-541c-4610-8ce8-318016db6e59
#
#               submitter_id  days_to_diagnosis               primary_diagnosis  \
# 0   TCGA-61-1740_diagnosis                0.0  Serous cystadenocarcinoma, NOS
# 1  TCGA-13-0761_diagnosis3              424.0                         Unknown
# 2  TCGA-13-0761_diagnosis2              424.0  Serous cystadenocarcinoma, NOS
# 3   TCGA-13-0761_diagnosis                0.0  Serous cystadenocarcinoma, NOS
# 4   TCGA-25-2390_diagnosis                0.0  Serous cystadenocarcinoma, NOS
#
# ...

# %%
pathology = pd.read_csv('ClinicalPreprocessing/ProcessedData/pathology_details.csv')
pathology.head()
# Out:
#                     pathology_detail_id                          diagnosis_id  \
# 0  ae9a7cf9-20ab-40c7-ade0-57ee2336e169  6bce9673-5223-59f5-b869-2366b5e46652
# 1  9bcca55a-33cd-466a-9b77-43c63fdfa378  fa91f476-c060-5d7c-8454-e8724950c497
# 2  b0c6a0a1-92c5-4ef8-83d7-04b142ef0444  dc0adbeb-b689-5242-9257-1d892eef26b1
# 3  2fd85542-2590-4e74-bf19-fdcc9554ff43  c3f472b3-884c-5a6a-b8ef-99c8a29a6b21
# 4  9da49dbf-bcf2-4abf-b47d-5ff663d1d7b0  1d60ab6b-010d-5421-9e30-11b38b71be6e
#
#                                 case_id                   submitter_id  \
# 0  005a6517-2e5a-4ea3-ab36-531522723607  TCGA-61-1740_pathology_detail
# 1  00630714-7ab3-44e1-afff-186300edae44  TCGA-13-0761_pathology_detail
# 2  01abf2cf-541c-4610-8ce8-318016db6e59  TCGA-25-2390_pathology_detail
# 3  01ea6354-137b-47f3-9021-a01a382b1147  TCGA-29-1766_pathology_detail
# 4  02594e5e-8751-47c1-9245-90c66984b665  TCGA-09-2051_pathology_detail
#
#   consistent_pathology_review vascular_invasion_present  \
# ...

# %%
treatments = pd.read_csv('ClinicalPreprocessing/ProcessedData/treatments.csv')
treatments.head()
# Out:
#                            treatment_id                          diagnosis_id  \
# 0  cb2dc0c4-bd49-58f3-aa30-fc5f15c8fd08  6bce9673-5223-59f5-b869-2366b5e46652
# 1  e458f367-1154-49ad-9075-b5ab3b8393f7  6bce9673-5223-59f5-b869-2366b5e46652
# 2  bc3f7a1c-f368-4b1d-9a38-d7d137243d40  f12065b8-bf43-4d3d-a6b2-f3e42796d92f
# 3  cf790fb7-935d-4d36-8b0f-e82fba6b0241  f12065b8-bf43-4d3d-a6b2-f3e42796d92f
# 4  7d185e00-771d-4f4a-93a3-3628a29aaef3  fa91f476-c060-5d7c-8454-e8724950c497
#
#                                 case_id             submitter_id  \
# 0  005a6517-2e5a-4ea3-ab36-531522723607   TCGA-61-1740_treatment
# 1  005a6517-2e5a-4ea3-ab36-531522723607  TCGA-61-1740_treatment2
# 2  00630714-7ab3-44e1-afff-186300edae44  TCGA-13-0761_treatment4
# 3  00630714-7ab3-44e1-afff-186300edae44  TCGA-13-0761_treatment5
# 4  00630714-7ab3-44e1-afff-186300edae44  TCGA-13-0761_treatment3
#
#                 treatment_type treatment_or_therapy treatment_intent_type  \
# ...

# %%
image_mapping = pd.read_csv('ClinicalPreprocessing/ProcessedData/image_clinical_annotation_map.csv')
image_mapping.head()
# Out:
#                                       image_filename  \
# 0  patient_TCGA-09-0364_series_1.3.6.1.4.1.14519....
# 1  patient_TCGA-09-2044_sop_1.3.6.1.4.1.14519.5.2...
# 2  patient_TCGA-09-2044_sop_1.3.6.1.4.1.14519.5.2...
# 3  patient_TCGA-09-2045_sop_1.3.6.1.4.1.14519.5.2...
# 4  patient_TCGA-09-2051_sop_1.3.6.1.4.1.14519.5.2...
#
#                                            full_path    patient_id  \
# 0  ../ImageCollection/dicom_images/patient_TCGA-0...  TCGA-09-0364
# 1  ../ImageCollection/dicom_images/patient_TCGA-0...  TCGA-09-2044
# 2  ../ImageCollection/dicom_images/patient_TCGA-0...  TCGA-09-2044
# 3  ../ImageCollection/dicom_images/patient_TCGA-0...  TCGA-09-2045
# 4  ../ImageCollection/dicom_images/patient_TCGA-0...  TCGA-09-2051
#
#                                 case_id  \
# 0  6746533a-8d0b-4ebc-87ec-49c8738121a8
# 1  7d03ddb6-f3fe-4b50-8bba-514aa65e7d0e
# 2  7d03ddb6-f3fe-4b50-8bba-514aa65e7d0e
# 3  3768d34f-1527-40db-b116-cd80cee5ec3a
# ...
